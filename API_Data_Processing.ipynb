# %%
import requests
import json
import pandas as pd
import numpy as np
from pprint import pprint as pp

# %%
generations = pd.read_json("API_datasets/gen.json")
regions = pd.read_json("API_datasets/region.json")

items = pd.read_json("API_datasets/item.json")
items_attr = pd.read_json("API_datasets/item_attr.json")
items_cat = pd.read_json("API_datasets/item_categ.json")

moves = pd.read_json("API_datasets/moves.json")
move_ail = pd.read_json("API_datasets/move_ail.json")
move_categ = pd.read_json("API_datasets/move_categ.json")
move_class = pd.read_json("API_datasets/move_class.json")
move_target = pd.read_json("API_datasets/move_target.json")

pkmn = pd.read_json("API_datasets/pokemon.json")
species = pd.read_json("API_datasets/species.json")
nature = pd.read_json("API_datasets/nature.json")
abilities = pd.read_json("API_datasets/abilities.json")
stats = pd.read_json("API_datasets/stat.json")
types = pd.read_json("API_datasets/types.json")

# %%
gen_df = pd.DataFrame(generations, columns=["id", "main_region", "moves", "name", "pokemon_species", "types"])
region_df = pd.DataFrame(regions, columns=["id", "locations", "main_generation", "name"])

items_df = pd.DataFrame(items, columns=["attributes", "category", "effect_entries", "id", "name"])
item_attributes_df = pd.DataFrame(items_attr, columns=["descriptions", "id", "items", "name"])
item_categories_df = pd.DataFrame(items_cat, columns=["id", "items", "name"])

moves_df = pd.DataFrame(moves, columns=["accuracy", "damage_class", "generation", "id", "learned_by_pokemon", "name", 
                                             "power", "pp", "type"])
move_ailments_df = pd.DataFrame(move_ail, columns=["id", "moves", "name"])
move_category_df = pd.DataFrame(move_categ, columns=["descriptions", "id", "moves", "name"])
move_class_df = pd.DataFrame(move_class, columns=["descriptions", "id", "moves", "name"])
move_target_df = pd.DataFrame(move_target, columns=["descriptions", "id", "moves", "name"])

pkmn_df = pd.DataFrame(pkmn, columns=["game_indices", "height", "id", "moves", "name", "weight"])
species_df = pd.DataFrame(species, columns=["evolves_from_species", "generation", "has_gender_differences", "id", 
                                                   "is_baby", "is_legendary", "is_mythical", "name", "varieties"])
ability_df = pd.DataFrame(abilities, columns=["effect_changes", "effect_entries", "generation", "id", "is_main_series", 
                                                   "name", "pokemon"])
nature_df = pd.DataFrame(nature, columns=["decreased_stat", "id", "increased_stat", "name"])
stat_df = pd.DataFrame(stats, columns=["affecting_moves", "affecting_natures", "id", "move_damage_class", "name"])
type_df = pd.DataFrame(types, columns=["damage_relations", "game_indices", "generation", "id", "name"])

# %%
gen_df = gen_df[["id", "name", "main_region", "pokemon_species", "moves", "types"]]
gen_df.columns = ["ID", "Gen_number", "Region_name", "New_pokemon", "New_moves", "New_types"]
region_df = region_df[["id", "name", "main_generation", "locations"]]
region_df.columns = ["ID", "Region_name", "Gen_number", "Locations"]

items_df = items_df[["id", "name", "attributes", "category", "effect_entries"]]
items_df.columns = ["ID", "Name", "Attributes", "Category", "Effect"]
item_attributes_df = item_attributes_df[["id", "name", "descriptions", "items"]]
item_attributes_df.columns = ["ID", "Name", "Descriptions", "Items"]
item_categories_df = item_categories_df[["id", "name", "items"]]
item_categories_df.columns = ["ID", "Name", "Items"]

moves_df = moves_df[["id", "name", "type", "power", "accuracy", "pp", "damage_class", "generation", "learned_by_pokemon"]]
moves_df.columns = ["ID", "Name", "Type", "Power", "Accuracy", "PP", "Damage_class", "Introducted_in", "Learned_by"]
move_ailments_df = move_ailments_df[["id", "name", "moves"]]
move_ailments_df.columns = ["ID", "Name", "Moves"]
move_category_df = move_category_df[["id", "name", "descriptions", "moves"]]
move_category_df.columns = ["ID", "Name", "Descriptions", "Moves"]
move_class_df = move_class_df[["id", "name", "descriptions", "moves"]]
move_class_df.columns = ["ID", "Name", "Descriptions", "Moves"]
move_target_df = move_target_df[["id", "name", "descriptions", "moves"]]
move_target_df.columns = ["ID", "Name", "Descriptions", "Moves"]

pkmn_df = pkmn_df[["id", "game_indices", "name", "moves", "height", "weight"]]
pkmn_df.columns = ["ID", "Game_index", "Name", "Moves", "Height", "Weight"]
species_df = species_df[["id", "name", "varieties", "generation", "evolves_from_species", "has_gender_differences",  "is_baby", 
                         "is_legendary", "is_mythical"]]
species_df.columns = ["ID", "Name", "Varieties", "Generation", "Evolves_from", "Has_gender_diff", "Is_baby", "Is_legendary",
                     "Is_mythical"]
ability_df = ability_df[["id", "name", "generation", "is_main_series", "effect_changes", "effect_entries", "pokemon"]]
ability_df.columns = ["ID", "Name", "Generation", "Is_Main_Series", "Effect_changes", "Effect_entries", "Pokemon"]
nature_df = nature_df[["id", "name", "decreased_stat", "increased_stat"]]
nature_df.columns = ["ID", "Name", "Decreased_stat", "Increased_stat"]
stat_df = stat_df[["id", "name", "affecting_moves", "affecting_natures", "move_damage_class"]]
stat_df.columns = ["ID", "Name", "Affecting_moves", "Affecting_natures", "Move_damage_class"]
type_df = type_df[["id", "game_indices", "name", "generation", "damage_relations"]]
type_df.columns = ["ID", "Game_index", "Name", "Introducted_in", "Damage_relations"]

# %% [markdown]
# ### Generations

# %%
gen_df
# Out:
#    ID       Gen_number                                        Region_name  \
# 0   1     generation-i  {'name': 'kanto', 'url': 'https://pokeapi.co/a...
# 1   2    generation-ii  {'name': 'johto', 'url': 'https://pokeapi.co/a...
# 2   3   generation-iii  {'name': 'hoenn', 'url': 'https://pokeapi.co/a...
# 3   4    generation-iv  {'name': 'sinnoh', 'url': 'https://pokeapi.co/...
# 4   5     generation-v  {'name': 'unova', 'url': 'https://pokeapi.co/a...
# 5   6    generation-vi  {'name': 'kalos', 'url': 'https://pokeapi.co/a...
# 6   7   generation-vii  {'name': 'alola', 'url': 'https://pokeapi.co/a...
# 7   8  generation-viii  {'name': 'galar', 'url': 'https://pokeapi.co/a...
#
#                                          New_pokemon  \
# 0  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1  [{'name': 'chikorita', 'url': 'https://pokeapi...
# 2  [{'name': 'treecko', 'url': 'https://pokeapi.c...
# 3  [{'name': 'turtwig', 'url': 'https://pokeapi.c...
# 4  [{'name': 'victini', 'url': 'https://pokeapi.c...
# 5  [{'name': 'chespin', 'url': 'https://pokeapi.c...
# 6  [{'name': 'rowlet', 'url': 'https://pokeapi.co...
# 7  [{'name': 'grookey', 'url': 'https://pokeapi.c...
#
#                                            New_moves  \
# 0  [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 1  [{'name': 'sketch', 'url': 'https://pokeapi.co...
# 2  [{'name': 'fake-out', 'url': 'https://pokeapi....
# 3  [{'name': 'roost', 'url': 'https://pokeapi.co/...
# 4  [{'name': 'hone-claws', 'url': 'https://pokeap...
# 5  [{'name': 'flying-press', 'url': 'https://poke...
# 6  [{'name': 'breakneck-blitz--physical', 'url': ...
# 7  [{'name': 'max-guard', 'url': 'https://pokeapi...
#
#                                            New_types
# 0  [{'name': 'normal', 'url': 'https://pokeapi.co...
# 1  [{'name': 'steel', 'url': 'https://pokeapi.co/...
# 2  [{'name': 'shadow', 'url': 'https://pokeapi.co...
# 3                                                 []
# 4                                                 []
# 5  [{'name': 'fairy', 'url': 'https://pokeapi.co/...
# 6                                                 []
# 7                                                 []

# %%
#Replace Gen_number with an integer
gen_df['Gen_number'] = gen_df['ID']

# %%
#Extract just the name from 'Region_name' lists
for i in (gen_df['ID'].values):
    gen_df.loc[i-1, 'Region_name'] = gen_df[gen_df['ID'] == i]['Region_name'][i-1]['name']

# %%
gen_df.Region_name = gen_df.Region_name.str.capitalize()

# %%
gen_df
# Out:
#    ID  Gen_number Region_name  \
# 0   1           1       Kanto
# 1   2           2       Johto
# 2   3           3       Hoenn
# 3   4           4      Sinnoh
# 4   5           5       Unova
# 5   6           6       Kalos
# 6   7           7       Alola
# 7   8           8       Galar
#
#                                          New_pokemon  \
# 0  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1  [{'name': 'chikorita', 'url': 'https://pokeapi...
# 2  [{'name': 'treecko', 'url': 'https://pokeapi.c...
# 3  [{'name': 'turtwig', 'url': 'https://pokeapi.c...
# 4  [{'name': 'victini', 'url': 'https://pokeapi.c...
# 5  [{'name': 'chespin', 'url': 'https://pokeapi.c...
# 6  [{'name': 'rowlet', 'url': 'https://pokeapi.co...
# 7  [{'name': 'grookey', 'url': 'https://pokeapi.c...
#
#                                            New_moves  \
# 0  [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 1  [{'name': 'sketch', 'url': 'https://pokeapi.co...
# 2  [{'name': 'fake-out', 'url': 'https://pokeapi....
# 3  [{'name': 'roost', 'url': 'https://pokeapi.co/...
# 4  [{'name': 'hone-claws', 'url': 'https://pokeap...
# 5  [{'name': 'flying-press', 'url': 'https://poke...
# 6  [{'name': 'breakneck-blitz--physical', 'url': ...
# 7  [{'name': 'max-guard', 'url': 'https://pokeapi...
#
#                                            New_types
# 0  [{'name': 'normal', 'url': 'https://pokeapi.co...
# 1  [{'name': 'steel', 'url': 'https://pokeapi.co/...
# 2  [{'name': 'shadow', 'url': 'https://pokeapi.co...
# 3                                                 []
# 4                                                 []
# 5  [{'name': 'fairy', 'url': 'https://pokeapi.co/...
# 6                                                 []
# 7                                                 []

# %% [markdown]
# ### Regions

# %%
region_df
# Out:
#    ID Region_name                                         Gen_number  \
# 0   1       kanto  {'name': 'generation-i', 'url': 'https://pokea...
# 1   2       johto  {'name': 'generation-ii', 'url': 'https://poke...
# 2   3       hoenn  {'name': 'generation-iii', 'url': 'https://pok...
# 3   4      sinnoh  {'name': 'generation-iv', 'url': 'https://poke...
# 4   5       unova  {'name': 'generation-v', 'url': 'https://pokea...
# 5   6       kalos  {'name': 'generation-vi', 'url': 'https://poke...
# 6   7       alola  {'name': 'generation-vii', 'url': 'https://pok...
# 7   8       galar  {'name': 'generation-viii', 'url': 'https://po...
#
#                                            Locations
# 0  [{'name': 'celadon-city', 'url': 'https://poke...
# 1  [{'name': 'blackthorn-city', 'url': 'https://p...
# 2  [{'name': 'petalburg-city', 'url': 'https://po...
# 3  [{'name': 'canalave-city', 'url': 'https://pok...
# 4  [{'name': 'unova-mystery-zone', 'url': 'https:...
# 5  [{'name': 'vaniville-town', 'url': 'https://po...
# 6  [{'name': 'alola-route-1--hauoli-outskirts', '...
# 7                                                 []

# %%
#Replace Gen_number with an integer
region_df['Gen_number'] = region_df['ID']

#Capitalize 'Region_name'
region_df.Region_name = region_df.Region_name.str.capitalize()

# %%
region_df
# Out:
#    ID Region_name  Gen_number  \
# 0   1       Kanto           1
# 1   2       Johto           2
# 2   3       Hoenn           3
# 3   4      Sinnoh           4
# 4   5       Unova           5
# 5   6       Kalos           6
# 6   7       Alola           7
# 7   8       Galar           8
#
#                                            Locations
# 0  [{'name': 'celadon-city', 'url': 'https://poke...
# 1  [{'name': 'blackthorn-city', 'url': 'https://p...
# 2  [{'name': 'petalburg-city', 'url': 'https://po...
# 3  [{'name': 'canalave-city', 'url': 'https://pok...
# 4  [{'name': 'unova-mystery-zone', 'url': 'https:...
# 5  [{'name': 'vaniville-town', 'url': 'https://po...
# 6  [{'name': 'alola-route-1--hauoli-outskirts', '...
# 7                                                 []

# %% [markdown]
# ### Items

# %%
#Capitalize names
items_df.Name = items_df.Name.str.capitalize()
items_df.tail()
# Out:
#         ID              Name Attributes  \
# 1602  1654  Shaderoot-carrot         []
# 1603  1655        Dynite-ore         []
# 1604  1656      Carrot-seeds         []
# 1605  1657     Ability-patch         []
# 1606  1658    Reins-of-unity         []
#
#                                                Category Effect
# 1602  {'name': 'plot-advancement', 'url': 'https://p...     []
# 1603  {'name': 'collectibles', 'url': 'https://pokea...     []
# 1604  {'name': 'plot-advancement', 'url': 'https://p...     []
# 1605  {'name': 'vitamins', 'url': 'https://pokeapi.c...     []
# 1606  {'name': 'plot-advancement', 'url': 'https://p...     []

# %%
#Ci sono degli ID mancanti nella colonna ID (per via di quelli skippati dalla API nell'ottenimento dei dati).
#Vado a resettare la colonna, da 1 a 1607 come dovrebbe essere
for i in range(0, items_df.shape[0]):
    items_df.loc[i, 'ID'] = i+1
    
items_df.tail()
# Out:
#         ID              Name Attributes  \
# 1602  1603  Shaderoot-carrot         []
# 1603  1604        Dynite-ore         []
# 1604  1605      Carrot-seeds         []
# 1605  1606     Ability-patch         []
# 1606  1607    Reins-of-unity         []
#
#                                                Category Effect
# 1602  {'name': 'plot-advancement', 'url': 'https://p...     []
# 1603  {'name': 'collectibles', 'url': 'https://pokea...     []
# 1604  {'name': 'plot-advancement', 'url': 'https://p...     []
# 1605  {'name': 'vitamins', 'url': 'https://pokeapi.c...     []
# 1606  {'name': 'plot-advancement', 'url': 'https://p...     []

# %%
#I mantain just the short effect in the Effect attribute
for i in (items_df['ID'].values):
    try:
        items_df.loc[i-1, 'Effect'] = items_df[items_df['ID'] == i]['Effect'][i-1][0]['short_effect']
    except IndexError:
        items_df.loc[i-1, 'Effect'] = np.NaN

# %%
items_df.tail()
# Out:
#         ID              Name Attributes  \
# 1602  1603  Shaderoot-carrot         []
# 1603  1604        Dynite-ore         []
# 1604  1605      Carrot-seeds         []
# 1605  1606     Ability-patch         []
# 1606  1607    Reins-of-unity         []
#
#                                                Category Effect
# 1602  {'name': 'plot-advancement', 'url': 'https://p...    NaN
# 1603  {'name': 'collectibles', 'url': 'https://pokea...    NaN
# 1604  {'name': 'plot-advancement', 'url': 'https://p...    NaN
# 1605  {'name': 'vitamins', 'url': 'https://pokeapi.c...    NaN
# 1606  {'name': 'plot-advancement', 'url': 'https://p...    NaN

# %%
items_df[items_df['Effect'].notnull()]
# Out:
#       ID             Name                                         Attributes  \
# 0      1      Master-ball  [{'name': 'countable', 'url': 'https://pokeapi...
# 1      2       Ultra-ball  [{'name': 'countable', 'url': 'https://pokeapi...
# 2      3       Great-ball  [{'name': 'countable', 'url': 'https://pokeapi...
# 3      4        Poke-ball  [{'name': 'countable', 'url': 'https://pokeapi...
# 4      5      Safari-ball  [{'name': 'countable', 'url': 'https://pokeapi...
# ..   ...              ...                                                ...
# 949  950     Roto-stealth                                                 []
# 950  951  Roto-hp-restore                                                 []
# 951  952  Roto-pp-restore                                                 []
# 952  953       Roto-boost                                                 []
# 953  954       Roto-catch                                                 []
#
#                                               Category  \
# 0    {'name': 'standard-balls', 'url': 'https://pok...
# 1    {'name': 'standard-balls', 'url': 'https://pok...
# 2    {'name': 'standard-balls', 'url': 'https://pok...
# 3    {'name': 'standard-balls', 'url': 'https://pok...
# 4    {'name': 'standard-balls', 'url': 'https://pok...
# ..                                                 ...
# 949  {'name': 'unused', 'url': 'https://pokeapi.co/...
# 950  {'name': 'unused', 'url': 'https://pokeapi.co/...
# 951  {'name': 'unused', 'url': 'https://pokeapi.co/...
# 952  {'name': 'unused', 'url': 'https://pokeapi.co/...
# 953  {'name': 'unused', 'url': 'https://pokeapi.co/...
#
#                                                 Effect
# 0                   Catches a wild Pokémon every time.
# 1    Tries to catch a wild Pokémon.  Success rate i...
# 2    Tries to catch a wild Pokémon.  Success rate i...
# 3                       Tries to catch a wild Pokémon.
# 4    Tries to catch a wild Pokémon in the Great Mar...
# ..                                                 ...
# 949                    XXX new effect for roto-stealth
# 950                 XXX new effect for roto-hp-restore
# 951                 XXX new effect for roto-pp-restore
# 952                      XXX new effect for roto-boost
# 953                      XXX new effect for roto-catch
#
# [954 rows x 5 columns]

# %%
items_df[items_df['Effect'].isnull()]
# Out:
#         ID              Name Attributes  \
# 954    955         Autograph         []
# 955    956       Pokemon-box         []
# 956    957   Medicine-pocket         []
# 957    958         Candy-jar         []
# 958    959   Power-up-pocket         []
# ...    ...               ...        ...
# 1602  1603  Shaderoot-carrot         []
# 1603  1604        Dynite-ore         []
# 1604  1605      Carrot-seeds         []
# 1605  1606     Ability-patch         []
# 1606  1607    Reins-of-unity         []
#
#                                                Category Effect
# 954   {'name': 'unused', 'url': 'https://pokeapi.co/...    NaN
# 955   {'name': 'unused', 'url': 'https://pokeapi.co/...    NaN
# 956   {'name': 'unused', 'url': 'https://pokeapi.co/...    NaN
# 957   {'name': 'unused', 'url': 'https://pokeapi.co/...    NaN
# 958   {'name': 'unused', 'url': 'https://pokeapi.co/...    NaN
# ...                                                 ...    ...
# 1602  {'name': 'plot-advancement', 'url': 'https://p...    NaN
# 1603  {'name': 'collectibles', 'url': 'https://pokea...    NaN
# 1604  {'name': 'plot-advancement', 'url': 'https://p...    NaN
# 1605  {'name': 'vitamins', 'url': 'https://pokeapi.c...    NaN
# 1606  {'name': 'plot-advancement', 'url': 'https://p...    NaN
#
# [653 rows x 5 columns]

# %% [markdown]
# I primi 954 strumenti hanno l'effetto, i successivi no.

# %%
#Stessa cosa per la categoria, mantengo solo il nome
for i in (items_df['ID'].values):
        items_df.loc[i-1, 'Category'] = items_df[items_df['ID'] == i]['Category'][i-1]['name']

# %%
items_df.Category = items_df.Category.str.capitalize()
items_df.head()
# Out:
#    ID         Name                                         Attributes  \
# 0   1  Master-ball  [{'name': 'countable', 'url': 'https://pokeapi...
# 1   2   Ultra-ball  [{'name': 'countable', 'url': 'https://pokeapi...
# 2   3   Great-ball  [{'name': 'countable', 'url': 'https://pokeapi...
# 3   4    Poke-ball  [{'name': 'countable', 'url': 'https://pokeapi...
# 4   5  Safari-ball  [{'name': 'countable', 'url': 'https://pokeapi...
#
#          Category                                             Effect
# 0  Standard-balls                 Catches a wild Pokémon every time.
# 1  Standard-balls  Tries to catch a wild Pokémon.  Success rate i...
# 2  Standard-balls  Tries to catch a wild Pokémon.  Success rate i...
# 3  Standard-balls                     Tries to catch a wild Pokémon.
# 4  Standard-balls  Tries to catch a wild Pokémon in the Great Mar...

# %%
for i in (items_df['ID'].values):
    temp = []
    for j in range(0, len(items_df[items_df['ID'] == i]['Attributes'][i-1])):
        temp.append(items_df[items_df['ID'] == i]['Attributes'][i-1][j]['name'])
    #In questo caso uso .at perchè .loc da problemi con l'assegnamento delle liste
    items_df.at[i-1, 'Attributes'] = temp

# %%
items_df.head()
# Out:
#    ID         Name                                         Attributes  \
# 0   1  Master-ball  [countable, consumable, usable-in-battle, hold...
# 1   2   Ultra-ball  [countable, consumable, usable-in-battle, hold...
# 2   3   Great-ball  [countable, consumable, usable-in-battle, hold...
# 3   4    Poke-ball  [countable, consumable, usable-in-battle, hold...
# 4   5  Safari-ball  [countable, consumable, usable-in-battle, hold...
#
#          Category                                             Effect
# 0  Standard-balls                 Catches a wild Pokémon every time.
# 1  Standard-balls  Tries to catch a wild Pokémon.  Success rate i...
# 2  Standard-balls  Tries to catch a wild Pokémon.  Success rate i...
# 3  Standard-balls                     Tries to catch a wild Pokémon.
# 4  Standard-balls  Tries to catch a wild Pokémon in the Great Mar...

# %%
#Salvataggio sia in .csv che in .json
items_df.to_json("API_datasets\DATASET PER INTEGRAZIONE\items.json.gz", orient='records', lines=True, compression='gzip')
items_df.to_csv("API_datasets\DATASET PER INTEGRAZIONE\items.csv")

# %% [markdown]
# ### Item attributes

# %%
item_attributes_df.Name = item_attributes_df.Name.str.capitalize()
item_attributes_df
# Out:
#    ID              Name                                       Descriptions  \
# 0   1         Countable  [{'description': 'Has a count in the bag', 'la...
# 1   2        Consumable  [{'description': 'Consumed when used', 'langua...
# 2   3  Usable-overworld  [{'description': 'Usable outside battle', 'lan...
# 3   4  Usable-in-battle  [{'description': 'Usable in battle', 'language...
# 4   5          Holdable  [{'description': 'Can be held by a Pokémon', '...
# 5   6  Holdable-passive  [{'description': 'Works passively when held', ...
# 6   7   Holdable-active  [{'description': 'Usable by a Pokémon when hel...
# 7   8       Underground  [{'description': 'Appears in Sinnoh Undergroun...
#
#                                                Items
# 0  [{'name': 'master-ball', 'url': 'https://pokea...
# 1  [{'name': 'master-ball', 'url': 'https://pokea...
# 2  [{'name': 'potion', 'url': 'https://pokeapi.co...
# 3  [{'name': 'master-ball', 'url': 'https://pokea...
# 4  [{'name': 'master-ball', 'url': 'https://pokea...
# 5                                                 []
# 6  [{'name': 'cheri-berry', 'url': 'https://pokea...
# 7  [{'name': 'revive', 'url': 'https://pokeapi.co...

# %%
#Extract just the description from 'Descriptions' lists
for i in (item_attributes_df['ID'].values):
    item_attributes_df.loc[i-1, 'Descriptions'] = item_attributes_df[item_attributes_df['ID'] == i]['Descriptions'][i-1][0]['description']

# %%
item_attributes_df
# Out:
#    ID              Name                   Descriptions  \
# 0   1         Countable         Has a count in the bag
# 1   2        Consumable             Consumed when used
# 2   3  Usable-overworld          Usable outside battle
# 3   4  Usable-in-battle               Usable in battle
# 4   5          Holdable       Can be held by a Pokémon
# 5   6  Holdable-passive      Works passively when held
# 6   7   Holdable-active  Usable by a Pokémon when held
# 7   8       Underground  Appears in Sinnoh Underground
#
#                                                Items
# 0  [{'name': 'master-ball', 'url': 'https://pokea...
# 1  [{'name': 'master-ball', 'url': 'https://pokea...
# 2  [{'name': 'potion', 'url': 'https://pokeapi.co...
# 3  [{'name': 'master-ball', 'url': 'https://pokea...
# 4  [{'name': 'master-ball', 'url': 'https://pokea...
# 5                                                 []
# 6  [{'name': 'cheri-berry', 'url': 'https://pokea...
# 7  [{'name': 'revive', 'url': 'https://pokeapi.co...

# %% [markdown]
# ### Item categories

# %%
item_categories_df.Name = item_categories_df.Name.str.capitalize()
item_categories_df.head()
# Out:
#    ID         Name                                              Items
# 0   1  Stat-boosts  [{'name': 'guard-spec', 'url': 'https://pokeap...
# 1   2  Effort-drop  [{'name': 'pomeg-berry', 'url': 'https://pokea...
# 2   3     Medicine  [{'name': 'cheri-berry', 'url': 'https://pokea...
# 3   4        Other  [{'name': 'enigma-berry', 'url': 'https://poke...
# 4   5   In-a-pinch  [{'name': 'liechi-berry', 'url': 'https://poke...

# %% [markdown]
# ### Moves

# %%
moves_df.Name = moves_df.Name.str.capitalize()
moves_df.tail()
# Out:
#         ID          Name                                               Type  \
# 839  10014   Shadow-hold  {'name': 'shadow', 'url': 'https://pokeapi.co/...
# 840  10015   Shadow-mist  {'name': 'shadow', 'url': 'https://pokeapi.co/...
# 841  10016  Shadow-panic  {'name': 'shadow', 'url': 'https://pokeapi.co/...
# 842  10017   Shadow-shed  {'name': 'shadow', 'url': 'https://pokeapi.co/...
# 843  10018    Shadow-sky  {'name': 'shadow', 'url': 'https://pokeapi.co/...
#
#      Power  Accuracy  PP                                       Damage_class  \
# 839    NaN       NaN NaN  {'name': 'status', 'url': 'https://pokeapi.co/...
# 840    NaN     100.0 NaN  {'name': 'status', 'url': 'https://pokeapi.co/...
# 841    NaN      90.0 NaN  {'name': 'status', 'url': 'https://pokeapi.co/...
# 842    NaN       NaN NaN  {'name': 'status', 'url': 'https://pokeapi.co/...
# 843    NaN       NaN NaN  {'name': 'status', 'url': 'https://pokeapi.co/...
#
#                                         Introducted_in Learned_by
# 839  {'name': 'generation-iii', 'url': 'https://pok...         []
# 840  {'name': 'generation-iii', 'url': 'https://pok...         []
# 841  {'name': 'generation-iii', 'url': 'https://pok...         []
# 842  {'name': 'generation-iii', 'url': 'https://pok...         []
# 843  {'name': 'generation-iii', 'url': 'https://pok...         []

# %%
#Ci sono degli ID mancanti nella colonna ID (per via di quelli skippati dalla API nell'ottenimento dei dati)
for i in range(0, moves_df.shape[0]):
    moves_df.loc[i, 'ID'] = i+1
    
moves_df.tail()
# Out:
#       ID          Name                                               Type  \
# 839  840   Shadow-hold  {'name': 'shadow', 'url': 'https://pokeapi.co/...
# 840  841   Shadow-mist  {'name': 'shadow', 'url': 'https://pokeapi.co/...
# 841  842  Shadow-panic  {'name': 'shadow', 'url': 'https://pokeapi.co/...
# 842  843   Shadow-shed  {'name': 'shadow', 'url': 'https://pokeapi.co/...
# 843  844    Shadow-sky  {'name': 'shadow', 'url': 'https://pokeapi.co/...
#
#      Power  Accuracy  PP                                       Damage_class  \
# 839    NaN       NaN NaN  {'name': 'status', 'url': 'https://pokeapi.co/...
# 840    NaN     100.0 NaN  {'name': 'status', 'url': 'https://pokeapi.co/...
# 841    NaN      90.0 NaN  {'name': 'status', 'url': 'https://pokeapi.co/...
# 842    NaN       NaN NaN  {'name': 'status', 'url': 'https://pokeapi.co/...
# 843    NaN       NaN NaN  {'name': 'status', 'url': 'https://pokeapi.co/...
#
#                                         Introducted_in Learned_by
# 839  {'name': 'generation-iii', 'url': 'https://pok...         []
# 840  {'name': 'generation-iii', 'url': 'https://pok...         []
# 841  {'name': 'generation-iii', 'url': 'https://pok...         []
# 842  {'name': 'generation-iii', 'url': 'https://pok...         []
# 843  {'name': 'generation-iii', 'url': 'https://pok...         []

# %%
#Extract just the type from 'Type' lists, damage class from 'Damage_class' lists and generation from 'Introducted_in' lists
for i in (moves_df['ID'].values):
    moves_df.loc[i-1, 'Type'] = moves_df[moves_df['ID'] == i]['Type'][i-1]['name']
    moves_df.loc[i-1, 'Damage_class'] = moves_df[moves_df['ID'] == i]['Damage_class'][i-1]['name']
    moves_df.loc[i-1, 'Introducted_in'] = moves_df[moves_df['ID'] == i]['Introducted_in'][i-1]['name']

# %%
moves_df.Type = moves_df.Type.str.capitalize()
moves_df.Damage_class = moves_df.Damage_class.str.capitalize()
moves_df.head()
# Out:
#    ID         Name      Type  Power  Accuracy    PP Damage_class  \
# 0   1        Pound    Normal   40.0     100.0  35.0     Physical
# 1   2  Karate-chop  Fighting   50.0     100.0  25.0     Physical
# 2   3  Double-slap    Normal   15.0      85.0  10.0     Physical
# 3   4  Comet-punch    Normal   18.0      85.0  15.0     Physical
# 4   5   Mega-punch    Normal   80.0      85.0  20.0     Physical
#
#   Introducted_in                                         Learned_by
# 0   generation-i  [{'name': 'clefairy', 'url': 'https://pokeapi....
# 1   generation-i  [{'name': 'mankey', 'url': 'https://pokeapi.co...
# 2   generation-i  [{'name': 'clefairy', 'url': 'https://pokeapi....
# 3   generation-i  [{'name': 'hitmonchan', 'url': 'https://pokeap...
# 4   generation-i  [{'name': 'charmander', 'url': 'https://pokeap...

# %%
for index, row in moves_df.iterrows():
    if row['Introducted_in'] == 'generation-i':
        moves_df.loc[index,'Introducted_in'] = '1'
    elif row['Introducted_in'] == 'generation-ii':
        moves_df.loc[index,'Introducted_in'] = '2'
    elif row['Introducted_in'] == 'generation-iii':
        moves_df.loc[index,'Introducted_in'] = '3'
    elif row['Introducted_in'] == 'generation-iv':
        moves_df.loc[index,'Introducted_in'] = '4'
    elif row['Introducted_in'] == 'generation-v':
        moves_df.loc[index,'Introducted_in'] = '5'
    elif row['Introducted_in'] == 'generation-vi':
        moves_df.loc[index,'Introducted_in'] = '6'
    elif row['Introducted_in'] == 'generation-vii':
        moves_df.loc[index,'Introducted_in'] = '7'
    elif row['Introducted_in'] == 'generation-viii':
        moves_df.loc[index,'Introducted_in'] = '8'

# %%
moves_df.head()
# Out:
#    ID         Name      Type  Power  Accuracy    PP Damage_class  \
# 0   1        Pound    Normal   40.0     100.0  35.0     Physical
# 1   2  Karate-chop  Fighting   50.0     100.0  25.0     Physical
# 2   3  Double-slap    Normal   15.0      85.0  10.0     Physical
# 3   4  Comet-punch    Normal   18.0      85.0  15.0     Physical
# 4   5   Mega-punch    Normal   80.0      85.0  20.0     Physical
#
#   Introducted_in                                         Learned_by
# 0              1  [{'name': 'clefairy', 'url': 'https://pokeapi....
# 1              1  [{'name': 'mankey', 'url': 'https://pokeapi.co...
# 2              1  [{'name': 'clefairy', 'url': 'https://pokeapi....
# 3              1  [{'name': 'hitmonchan', 'url': 'https://pokeap...
# 4              1  [{'name': 'charmander', 'url': 'https://pokeap...

# %%
moves_df.tail()
# Out:
#       ID          Name    Type  Power  Accuracy  PP Damage_class  \
# 839  840   Shadow-hold  Shadow    NaN       NaN NaN       Status
# 840  841   Shadow-mist  Shadow    NaN     100.0 NaN       Status
# 841  842  Shadow-panic  Shadow    NaN      90.0 NaN       Status
# 842  843   Shadow-shed  Shadow    NaN       NaN NaN       Status
# 843  844    Shadow-sky  Shadow    NaN       NaN NaN       Status
#
#     Introducted_in Learned_by
# 839              3         []
# 840              3         []
# 841              3         []
# 842              3         []
# 843              3         []

# %%
#Salvataggio sia in .csv che in .json
moves_df.to_json("API_datasets\DATASET PER INTEGRAZIONE\moves.json.gz", orient='records', lines=True, compression='gzip')
moves_df.to_csv("API_datasets\DATASET PER INTEGRAZIONE\moves.csv")

# %% [markdown]
# ### Move ailments

# %%
move_ailments_df.head()
# Out:
#    ID       Name                                              Moves
# 0  -1    unknown  [{'name': 'tri-attack', 'url': 'https://pokeap...
# 1   0       none  [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 2   1  paralysis  [{'name': 'thunder-punch', 'url': 'https://pok...
# 3   2      sleep  [{'name': 'sing', 'url': 'https://pokeapi.co/a...
# 4   3     freeze  [{'name': 'ice-punch', 'url': 'https://pokeapi...

# %%
#Resetto gli ID che partono da -1
for i in range(0, move_ailments_df.shape[0]):
    move_ailments_df.loc[i, 'ID'] = i+1
    
move_ailments_df.head()
# Out:
#    ID       Name                                              Moves
# 0   1    unknown  [{'name': 'tri-attack', 'url': 'https://pokeap...
# 1   2       none  [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 2   3  paralysis  [{'name': 'thunder-punch', 'url': 'https://pok...
# 3   4      sleep  [{'name': 'sing', 'url': 'https://pokeapi.co/a...
# 4   5     freeze  [{'name': 'ice-punch', 'url': 'https://pokeapi...

# %%
move_ailments_df.Name = move_ailments_df.Name.str.capitalize()
move_ailments_df.head()
# Out:
#    ID       Name                                              Moves
# 0   1    Unknown  [{'name': 'tri-attack', 'url': 'https://pokeap...
# 1   2       None  [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 2   3  Paralysis  [{'name': 'thunder-punch', 'url': 'https://pok...
# 3   4      Sleep  [{'name': 'sing', 'url': 'https://pokeapi.co/a...
# 4   5     Freeze  [{'name': 'ice-punch', 'url': 'https://pokeapi...

# %% [markdown]
# ### Move categories

# %%
move_category_df.Name = move_category_df.Name.str.capitalize()
move_category_df.head()
# Out:
#    ID            Name                                       Descriptions  \
# 0   0          Damage  [{'description': 'Inflicts damage', 'language'...
# 1   1         Ailment  [{'description': 'No damage; inflicts status a...
# 2   2  Net-good-stats  [{'description': 'No damage; lowers target's s...
# 3   3            Heal  [{'description': 'No damage; heals the user', ...
# 4   4  Damage+ailment  [{'description': 'Inflicts damage; inflicts st...
#
#                                                Moves
# 0  [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 1  [{'name': 'sing', 'url': 'https://pokeapi.co/a...
# 2  [{'name': 'swords-dance', 'url': 'https://poke...
# 3  [{'name': 'recover', 'url': 'https://pokeapi.c...
# 4  [{'name': 'fire-punch', 'url': 'https://pokeap...

# %%
#Resetto gli ID
for i in range(0, move_category_df.shape[0]):
    move_category_df.loc[i, 'ID'] = i+1
    
move_category_df.head()
# Out:
#    ID            Name                                       Descriptions  \
# 0   1          Damage  [{'description': 'Inflicts damage', 'language'...
# 1   2         Ailment  [{'description': 'No damage; inflicts status a...
# 2   3  Net-good-stats  [{'description': 'No damage; lowers target's s...
# 3   4            Heal  [{'description': 'No damage; heals the user', ...
# 4   5  Damage+ailment  [{'description': 'Inflicts damage; inflicts st...
#
#                                                Moves
# 0  [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 1  [{'name': 'sing', 'url': 'https://pokeapi.co/a...
# 2  [{'name': 'swords-dance', 'url': 'https://poke...
# 3  [{'name': 'recover', 'url': 'https://pokeapi.c...
# 4  [{'name': 'fire-punch', 'url': 'https://pokeap...

# %%
#Extract just the description from 'Descriptions' lists
for i in (move_category_df['ID'].values):
    move_category_df.loc[i-1, 'Descriptions'] = move_category_df[move_category_df['ID'] == i]['Descriptions'][i-1][0]['description']

# %%
move_category_df.head()
# Out:
#    ID            Name                                       Descriptions  \
# 0   1          Damage                                    Inflicts damage
# 1   2         Ailment                 No damage; inflicts status ailment
# 2   3  Net-good-stats  No damage; lowers target's stats or raises use...
# 3   4            Heal                          No damage; heals the user
# 4   5  Damage+ailment           Inflicts damage; inflicts status ailment
#
#                                                Moves
# 0  [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 1  [{'name': 'sing', 'url': 'https://pokeapi.co/a...
# 2  [{'name': 'swords-dance', 'url': 'https://poke...
# 3  [{'name': 'recover', 'url': 'https://pokeapi.c...
# 4  [{'name': 'fire-punch', 'url': 'https://pokeap...

# %% [markdown]
# ### Move classes

# %%
move_class_df.Name = move_class_df.Name.str.capitalize()
move_class_df.head()
# Out:
#    ID      Name                                       Descriptions  \
# 0   1    Status  [{'description': 'ダメージない', 'language': {'name'...
# 1   2  Physical  [{'description': 'ぶつりのダメージ。こうげきとぼうぎょを行使する', 'l...
# 2   3   Special  [{'description': 'とくしゅのダメージ。とくこうととくぼうを行使する', '...
#
#                                                Moves
# 0  [{'name': 'swords-dance', 'url': 'https://poke...
# 1  [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 2  [{'name': 'razor-wind', 'url': 'https://pokeap...

# %%
#Tengo solo la descrizione in inglese. Essendo solo 3 dati conviene semplicemente trascrivere a mano la descrizione:
for i in range (0,3):
    print(move_class_df['Descriptions'][i][4])
# Out:
# {'description': 'No damage', 'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'}}
# {'description': 'Physical damage, controlled by Attack and Defense', 'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'}}
# {'description': 'Special damage, controlled by Special Attack and Special Defense', 'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'}}

# %%
#La descrizione per 'status' è 'No damage'
move_class_df.loc[0,'Descriptions'] = 'No damage'

#La descrizione per 'physical' è 'Physical damage, controlled by Attack and Defense'
move_class_df.loc[1,'Descriptions'] = 'Physical damage, controlled by Attack and Defense'

#La descrizione per 'physical' è 'Special damage, controlled by Special Attack and Special Defense'
move_class_df.loc[2,'Descriptions'] = 'Special damage, controlled by Special Attack and Special Defense'

move_class_df
# Out:
#    ID      Name                                       Descriptions  \
# 0   1    Status                                          No damage
# 1   2  Physical  Physical damage, controlled by Attack and Defense
# 2   3   Special  Special damage, controlled by Special Attack a...
#
#                                                Moves
# 0  [{'name': 'swords-dance', 'url': 'https://poke...
# 1  [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 2  [{'name': 'razor-wind', 'url': 'https://pokeap...

# %% [markdown]
# ### Move targets

# %%
move_target_df.Name = move_target_df.Name.str.capitalize()
move_target_df
# Out:
#     ID                       Name  \
# 0    1              Specific-move
# 1    2  Selected-pokemon-me-first
# 2    3                       Ally
# 3    4                Users-field
# 4    5               User-or-ally
# 5    6            Opponents-field
# 6    7                       User
# 7    8            Random-opponent
# 8    9          All-other-pokemon
# 9   10           Selected-pokemon
# 10  11              All-opponents
# 11  12               Entire-field
# 12  13            User-and-allies
# 13  14                All-pokemon
# 14  15                 All-allies
#
#                                          Descriptions  \
# 0   [{'description': 'Eine spezifische Fähigkeit. ...
# 1   [{'description': 'Ein anderes vom Trainer ausg...
# 2   [{'description': 'Die Partner des Anwenders (w...
# 3   [{'description': 'Die Seite des Anwenders auf ...
# 4   [{'description': 'Entweder der Anwender oder s...
# 5   [{'description': 'Die andere Seite des Feldes....
# 6   [{'description': 'Der Anwender.', 'language': ...
# 7   [{'description': 'Ein zufälliges gegnerische P...
# 8   [{'description': 'Jedes andere Pokémon auf dem...
# 9   [{'description': 'Ein anderes Pokémon auf dem ...
# 10  [{'description': 'Alle gegnerischen Pokémon.',...
# 11  [{'description': 'Das komplette Feld.  Betriff...
# 12  [{'description': 'Der Anwender und seine Partn...
# 13  [{'description': 'Jedes Pokémon auf dem Feld.'...
# 14  [{'description': 'All of the user's allies.', ...
#
#                                                 Moves
# 0   [{'name': 'counter', 'url': 'https://pokeapi.c...
# 1   [{'name': 'me-first', 'url': 'https://pokeapi....
# 2   [{'name': 'helping-hand', 'url': 'https://poke...
# 3   [{'name': 'mist', 'url': 'https://pokeapi.co/a...
# 4   [{'name': 'acupressure', 'url': 'https://pokea...
# 5   [{'name': 'spikes', 'url': 'https://pokeapi.co...
# 6   [{'name': 'swords-dance', 'url': 'https://poke...
# 7   [{'name': 'thrash', 'url': 'https://pokeapi.co...
# 8   [{'name': 'surf', 'url': 'https://pokeapi.co/a...
# 9   [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 10  [{'name': 'razor-wind', 'url': 'https://pokeap...
# 11  [{'name': 'haze', 'url': 'https://pokeapi.co/a...
# 12  [{'name': 'heal-bell', 'url': 'https://pokeapi...
# 13  [{'name': 'perish-song', 'url': 'https://pokea...
# 14                                                 []

# %%
#Vale per tutte le prime 14 righe
move_target_df['Descriptions'][0][1]
# Out:
# {'description': 'One specific move.  How this move is chosen depends upon on the move being used.',
#  'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'}}

# %%
#Ultima riga
move_target_df['Descriptions'][14][0]
# Out:
# {'description': "All of the user's allies.",
#  'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'}}

# %%
#Tutte le righe della descrizione hanno la descrizione in tedesco al primo posto e in inglese al secondo, eccezion fatta per
#l'ultima riga che ha solo la descrizione in inglese

for i in (move_target_df['ID'].values):
    if i <= 14:
        move_target_df.loc[i-1, 'Descriptions'] = move_target_df[move_target_df['ID'] == i]['Descriptions'][i-1][1]['description']
    else:
        move_target_df.loc[i-1, 'Descriptions'] = move_target_df[move_target_df['ID'] == i]['Descriptions'][i-1][0]['description']

# %%
move_target_df
# Out:
#     ID                       Name  \
# 0    1              Specific-move
# 1    2  Selected-pokemon-me-first
# 2    3                       Ally
# 3    4                Users-field
# 4    5               User-or-ally
# 5    6            Opponents-field
# 6    7                       User
# 7    8            Random-opponent
# 8    9          All-other-pokemon
# 9   10           Selected-pokemon
# 10  11              All-opponents
# 11  12               Entire-field
# 12  13            User-and-allies
# 13  14                All-pokemon
# 14  15                 All-allies
#
#                                          Descriptions  \
# 0   One specific move.  How this move is chosen de...
# 1   One other Pokémon on the field, selected by th...
# 2                           The user's ally (if any).
# 3   The user's side of the field.  Affects the use...
# 4   Either the user or its ally, selected by the t...
# 5   The opposing side of the field.  Affects oppos...
# 6                                           The user.
# 7           One opposing Pokémon, selected at random.
# 8                   Every other Pokémon on the field.
# 9   One other Pokémon on the field, selected by th...
# 10                              All opposing Pokémon.
# 11            The entire field.  Affects all Pokémon.
# 12                           The user and its allies.
# 13                        Every Pokémon on the field.
# 14                          All of the user's allies.
#
#                                                 Moves
# 0   [{'name': 'counter', 'url': 'https://pokeapi.c...
# 1   [{'name': 'me-first', 'url': 'https://pokeapi....
# 2   [{'name': 'helping-hand', 'url': 'https://poke...
# 3   [{'name': 'mist', 'url': 'https://pokeapi.co/a...
# 4   [{'name': 'acupressure', 'url': 'https://pokea...
# 5   [{'name': 'spikes', 'url': 'https://pokeapi.co...
# 6   [{'name': 'swords-dance', 'url': 'https://poke...
# 7   [{'name': 'thrash', 'url': 'https://pokeapi.co...
# 8   [{'name': 'surf', 'url': 'https://pokeapi.co/a...
# 9   [{'name': 'pound', 'url': 'https://pokeapi.co/...
# 10  [{'name': 'razor-wind', 'url': 'https://pokeap...
# 11  [{'name': 'haze', 'url': 'https://pokeapi.co/a...
# 12  [{'name': 'heal-bell', 'url': 'https://pokeapi...
# 13  [{'name': 'perish-song', 'url': 'https://pokea...
# 14                                                 []

# %% [markdown]
# ### Pokemon

# %%
#Questo dataframe contiene tutte le versioni dei vari pokemon, comprese le varianti speciali
pkmn_df.Name = pkmn_df.Name.str.capitalize()
pkmn_df.drop('Game_index', axis=1, inplace=True)
pkmn_df.head()
# Out:
#    ID        Name                                              Moves  Height  \
# 0   1   Bulbasaur  [{'move': {'name': 'razor-wind', 'url': 'https...       7
# 1   2     Ivysaur  [{'move': {'name': 'swords-dance', 'url': 'htt...      10
# 2   3    Venusaur  [{'move': {'name': 'swords-dance', 'url': 'htt...      20
# 3   4  Charmander  [{'move': {'name': 'mega-punch', 'url': 'https...       6
# 4   5  Charmeleon  [{'move': {'name': 'mega-punch', 'url': 'https...      11
#
#    Weight
# 0      69
# 1     130
# 2    1000
# 3      85
# 4     190

# %%
#Salvataggio sia in .csv che in .json
pkmn_df.to_json("API_datasets\DATASET PER INTEGRAZIONE\pokemon.json.gz", orient='records', lines=True, compression='gzip')
pkmn_df.to_csv("API_datasets\DATASET PER INTEGRAZIONE\pokemon.csv")

# %% [markdown]
# ### Species

# %%
#Questo dataframe contiene una riga per ciascuna specie, nella colonna 'Varieties' sono presenti le varie forme alternative
#Tengo la colonna 'Varieties' così com'è, la considero una relazione
species_df.Name = species_df.Name.str.capitalize()
species_df.head()
# Out:
#    ID        Name                                          Varieties  \
# 0   1   Bulbasaur  [{'is_default': True, 'pokemon': {'name': 'bul...
# 1   2     Ivysaur  [{'is_default': True, 'pokemon': {'name': 'ivy...
# 2   3    Venusaur  [{'is_default': True, 'pokemon': {'name': 'ven...
# 3   4  Charmander  [{'is_default': True, 'pokemon': {'name': 'cha...
# 4   5  Charmeleon  [{'is_default': True, 'pokemon': {'name': 'cha...
#
#                                           Generation  \
# 0  {'name': 'generation-i', 'url': 'https://pokea...
# 1  {'name': 'generation-i', 'url': 'https://pokea...
# 2  {'name': 'generation-i', 'url': 'https://pokea...
# 3  {'name': 'generation-i', 'url': 'https://pokea...
# 4  {'name': 'generation-i', 'url': 'https://pokea...
#
#                                         Evolves_from  Has_gender_diff  \
# 0                                               None            False
# 1  {'name': 'bulbasaur', 'url': 'https://pokeapi....            False
# 2  {'name': 'ivysaur', 'url': 'https://pokeapi.co...             True
# 3                                               None            False
# 4  {'name': 'charmander', 'url': 'https://pokeapi...            False
#
#    Is_baby  Is_legendary  Is_mythical
# 0    False         False        False
# 1    False         False        False
# 2    False         False        False
# 3    False         False        False
# 4    False         False        False

# %%
#Extract just the generation from 'Generation' lists 
for i in (species_df['ID'].values):
    species_df.loc[i-1, 'Generation'] = species_df[species_df['ID'] == i]['Generation'][i-1]['name']

# %%
species_df.head()
# Out:
#    ID        Name                                          Varieties  \
# 0   1   Bulbasaur  [{'is_default': True, 'pokemon': {'name': 'bul...
# 1   2     Ivysaur  [{'is_default': True, 'pokemon': {'name': 'ivy...
# 2   3    Venusaur  [{'is_default': True, 'pokemon': {'name': 'ven...
# 3   4  Charmander  [{'is_default': True, 'pokemon': {'name': 'cha...
# 4   5  Charmeleon  [{'is_default': True, 'pokemon': {'name': 'cha...
#
#      Generation                                       Evolves_from  \
# 0  generation-i                                               None
# 1  generation-i  {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 2  generation-i  {'name': 'ivysaur', 'url': 'https://pokeapi.co...
# 3  generation-i                                               None
# 4  generation-i  {'name': 'charmander', 'url': 'https://pokeapi...
#
#    Has_gender_diff  Is_baby  Is_legendary  Is_mythical
# 0            False    False         False        False
# 1            False    False         False        False
# 2             True    False         False        False
# 3            False    False         False        False
# 4            False    False         False        False

# %%
#Extract just the name from 'Evolves_from' lists 
for i in (species_df['ID'].values):
    try:
        species_df.loc[i-1, 'Evolves_from'] = species_df[species_df['ID'] == i]['Evolves_from'][i-1]['name']
    except TypeError:
        species_df.loc[i-1, 'Evolves_from'] = np.NaN

# %%
species_df.Evolves_from = species_df.Evolves_from.str.capitalize()
species_df.head()
# Out:
#    ID        Name                                          Varieties  \
# 0   1   Bulbasaur  [{'is_default': True, 'pokemon': {'name': 'bul...
# 1   2     Ivysaur  [{'is_default': True, 'pokemon': {'name': 'ivy...
# 2   3    Venusaur  [{'is_default': True, 'pokemon': {'name': 'ven...
# 3   4  Charmander  [{'is_default': True, 'pokemon': {'name': 'cha...
# 4   5  Charmeleon  [{'is_default': True, 'pokemon': {'name': 'cha...
#
#      Generation Evolves_from  Has_gender_diff  Is_baby  Is_legendary  \
# 0  generation-i          NaN            False    False         False
# 1  generation-i    Bulbasaur            False    False         False
# 2  generation-i      Ivysaur             True    False         False
# 3  generation-i          NaN            False    False         False
# 4  generation-i   Charmander            False    False         False
#
#    Is_mythical
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
#Aggiungo una colonna che riassume le colonne 'Is_baby', 'Is_legendary' e 'Is_mythical' (se tutte sono false li chiamo 'Common')
for index, row in species_df.iterrows():
    if row['Is_baby'] == True:
        species_df.loc[index,'Rarity'] = 'Baby'
    elif row['Is_legendary'] == True:
        species_df.loc[index,'Rarity'] = 'Legendary'
    elif row['Is_mythical'] == True:
        species_df.loc[index,'Rarity'] = 'Mythical'
    else:
        species_df.loc[index,'Rarity'] = 'Common'

# %%
species_df.drop(['Is_baby', 'Is_legendary', 'Is_mythical'], axis=1, inplace=True)
species_df.tail(15)
# Out:
#       ID       Name                                          Varieties  \
# 883  884  Duraludon  [{'is_default': True, 'pokemon': {'name': 'dur...
# 884  885     Dreepy  [{'is_default': True, 'pokemon': {'name': 'dre...
# 885  886   Drakloak  [{'is_default': True, 'pokemon': {'name': 'dra...
# 886  887  Dragapult  [{'is_default': True, 'pokemon': {'name': 'dra...
# 887  888     Zacian  [{'is_default': True, 'pokemon': {'name': 'zac...
# 888  889  Zamazenta  [{'is_default': True, 'pokemon': {'name': 'zam...
# 889  890  Eternatus  [{'is_default': True, 'pokemon': {'name': 'ete...
# 890  891      Kubfu  [{'is_default': True, 'pokemon': {'name': 'kub...
# 891  892    Urshifu  [{'is_default': True, 'pokemon': {'name': 'urs...
# 892  893     Zarude  [{'is_default': True, 'pokemon': {'name': 'zar...
# 893  894  Regieleki  [{'is_default': True, 'pokemon': {'name': 'reg...
# 894  895  Regidrago  [{'is_default': True, 'pokemon': {'name': 'reg...
# 895  896  Glastrier  [{'is_default': True, 'pokemon': {'name': 'gla...
# 896  897  Spectrier  [{'is_default': True, 'pokemon': {'name': 'spe...
# 897  898    Calyrex  [{'is_default': True, 'pokemon': {'name': 'cal...
#
#           Generation Evolves_from  Has_gender_diff     Rarity
# 883  generation-viii          NaN            False     Common
# 884  generation-viii          NaN            False     Common
# 885  generation-viii       Dreepy            False     Common
# 886  generation-viii     Drakloak            False     Common
# 887  generation-viii          NaN            False  Legendary
# 888  generation-viii          NaN            False  Legendary
# 889  generation-viii          NaN            False  Legendary
# 890  generation-viii          NaN            False  Legendary
# 891  generation-viii        Kubfu            False  Legendary
# 892  generation-viii          NaN            False   Mythical
# 893  generation-viii          NaN            False  Legendary
# 894  generation-viii          NaN            False  Legendary
# 895  generation-viii          NaN            False  Legendary
# 896  generation-viii          NaN            False  Legendary
# 897  generation-viii          NaN            False  Legendary

# %%
for index, row in species_df.iterrows():
    if row['Generation'] == 'generation-i':
        species_df.loc[index,'Generation'] = '1'
    elif row['Generation'] == 'generation-ii':
        species_df.loc[index,'Generation'] = '2'
    elif row['Generation'] == 'generation-iii':
        species_df.loc[index,'Generation'] = '3'
    elif row['Generation'] == 'generation-iv':
        species_df.loc[index,'Generation'] = '4'
    elif row['Generation'] == 'generation-v':
        species_df.loc[index,'Generation'] = '5'
    elif row['Generation'] == 'generation-vi':
        species_df.loc[index,'Generation'] = '6'
    elif row['Generation'] == 'generation-vii':
        species_df.loc[index,'Generation'] = '7'
    elif row['Generation'] == 'generation-viii':
        species_df.loc[index,'Generation'] = '8'

# %%
species_df.head()
# Out:
#    ID        Name                                          Varieties  \
# 0   1   Bulbasaur  [{'is_default': True, 'pokemon': {'name': 'bul...
# 1   2     Ivysaur  [{'is_default': True, 'pokemon': {'name': 'ivy...
# 2   3    Venusaur  [{'is_default': True, 'pokemon': {'name': 'ven...
# 3   4  Charmander  [{'is_default': True, 'pokemon': {'name': 'cha...
# 4   5  Charmeleon  [{'is_default': True, 'pokemon': {'name': 'cha...
#
#   Generation Evolves_from  Has_gender_diff  Rarity
# 0          1          NaN            False  Common
# 1          1    Bulbasaur            False  Common
# 2          1      Ivysaur             True  Common
# 3          1          NaN            False  Common
# 4          1   Charmander            False  Common

# %%
species_df.tail()
# Out:
#       ID       Name                                          Varieties  \
# 893  894  Regieleki  [{'is_default': True, 'pokemon': {'name': 'reg...
# 894  895  Regidrago  [{'is_default': True, 'pokemon': {'name': 'reg...
# 895  896  Glastrier  [{'is_default': True, 'pokemon': {'name': 'gla...
# 896  897  Spectrier  [{'is_default': True, 'pokemon': {'name': 'spe...
# 897  898    Calyrex  [{'is_default': True, 'pokemon': {'name': 'cal...
#
#     Generation Evolves_from  Has_gender_diff     Rarity
# 893          8          NaN            False  Legendary
# 894          8          NaN            False  Legendary
# 895          8          NaN            False  Legendary
# 896          8          NaN            False  Legendary
# 897          8          NaN            False  Legendary

# %%
#Salvataggio sia in .csv che in .json
species_df.to_json("API_datasets\DATASET PER INTEGRAZIONE\species.json.gz", orient='records', lines=True, compression='gzip')
species_df.to_csv("API_datasets\DATASET PER INTEGRAZIONE\species.csv")

# %% [markdown]
# ### Abilities

# %%
ability_df.Name = ability_df.Name.str.capitalize()

#Resetto gli IDs
for i in range(0, ability_df.shape[0]):
    ability_df.loc[i, 'ID'] = i+1
    
ability_df.tail()
# Out:
#       ID       Name                                         Generation  \
# 322  323     Run-up  {'name': 'generation-v', 'url': 'https://pokea...
# 323  324  Conqueror  {'name': 'generation-v', 'url': 'https://pokea...
# 324  325    Shackle  {'name': 'generation-v', 'url': 'https://pokea...
# 325  326      Decoy  {'name': 'generation-v', 'url': 'https://pokea...
# 326  327     Shield  {'name': 'generation-v', 'url': 'https://pokea...
#
#      Is_Main_Series Effect_changes Effect_entries Pokemon
# 322           False             []             []      []
# 323           False             []             []      []
# 324           False             []             []      []
# 325           False             []             []      []
# 326           False             []             []      []

# %%
#Extract just the generation from 'Generation' lists 
for i in (ability_df['ID'].values):
    ability_df.loc[i-1, 'Generation'] = ability_df[ability_df['ID'] == i]['Generation'][i-1]['name']

# %%
ability_df.tail()
# Out:
#       ID       Name    Generation  Is_Main_Series Effect_changes  \
# 322  323     Run-up  generation-v           False             []
# 323  324  Conqueror  generation-v           False             []
# 324  325    Shackle  generation-v           False             []
# 325  326      Decoy  generation-v           False             []
# 326  327     Shield  generation-v           False             []
#
#     Effect_entries Pokemon
# 322             []      []
# 323             []      []
# 324             []      []
# 325             []      []
# 326             []      []

# %%
#A noi interessano solo le abilità disponibili nei giochi della serie principale, quindi:
mainseries_ability_df = ability_df[ability_df['Is_Main_Series'] == True]
mainseries_ability_df.tail()
# Out:
#       ID              Name       Generation  Is_Main_Series Effect_changes  \
# 262  263       Dragons-maw  generation-viii            True             []
# 263  264    Chilling-neigh  generation-viii            True             []
# 264  265        Grim-neigh  generation-viii            True             []
# 265  266  As-one-glastrier  generation-viii            True             []
# 266  267  As-one-spectrier  generation-viii            True             []
#
#     Effect_entries                                            Pokemon
# 262             []  [{'is_hidden': False, 'pokemon': {'name': 'reg...
# 263             []  [{'is_hidden': False, 'pokemon': {'name': 'gla...
# 264             []  [{'is_hidden': False, 'pokemon': {'name': 'spe...
# 265             []  [{'is_hidden': False, 'pokemon': {'name': 'cal...
# 266             []  [{'is_hidden': False, 'pokemon': {'name': 'cal...

# %% [markdown]
# La colonna 'Effect_changes' contiene i cambiamenti degli effetti dell'abilità col passare delle versioni. Lascio la colonna per sicurezza, anche se a noi interesse l'effetto attuale, che è contenuto nella colonna 'Effect_entries'. Ha senso comunque fare integrazione coi dati dello scraping.

# %%
#Fino all'abilità con ID=191 abbiamo sia la descrizione in tedesco che in inglese. Dall' ID=192 fino alla fine abbiamo solo la 
#descrizione in inglese

for i in (mainseries_ability_df['ID'].values):
    try:
        if i <= 191:
            mainseries_ability_df.loc[i-1, 'Effect_entries'] = mainseries_ability_df[mainseries_ability_df['ID'] == i]['Effect_entries'][i-1][1]['effect']
        else:
            mainseries_ability_df.loc[i-1, 'Effect_entries'] = mainseries_ability_df[mainseries_ability_df['ID'] == i]['Effect_entries'][i-1][0]['effect']
    except IndexError:
        mainseries_ability_df.loc[i-1, 'Effect_entries'] = np.NaN
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
mainseries_ability_df.head()
# Out:
#    ID          Name      Generation  Is_Main_Series  \
# 0   1        Stench  generation-iii            True
# 1   2       Drizzle  generation-iii            True
# 2   3   Speed-boost  generation-iii            True
# 3   4  Battle-armor  generation-iii            True
# 4   5        Sturdy  generation-iii            True
#
#                                       Effect_changes  \
# 0  [{'effect_entries': [{'effect': 'Hat im Kampf ...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'effect_entries': [{'effect': 'Verhindert ke...
#
#                                       Effect_entries  \
# 0  This Pokémon's damaging moves have a 10% chanc...
# 1  The weather changes to rain when this Pokémon ...
# 2  This Pokémon's Speed rises one stage after eac...
# 3  Moves cannot score critical hits against this ...
# 4  When this Pokémon is at full HP, any hit that ...
#
#                                              Pokemon
# 0  [{'is_hidden': True, 'pokemon': {'name': 'gloo...
# 1  [{'is_hidden': True, 'pokemon': {'name': 'poli...
# 2  [{'is_hidden': False, 'pokemon': {'name': 'yan...
# 3  [{'is_hidden': True, 'pokemon': {'name': 'cubo...
# 4  [{'is_hidden': False, 'pokemon': {'name': 'geo...

# %%
for index, row in mainseries_ability_df.iterrows():
    if row['Generation'] == 'generation-i':
        mainseries_ability_df.loc[index,'Generation'] = '1'
    elif row['Generation'] == 'generation-ii':
        mainseries_ability_df.loc[index,'Generation'] = '2'
    elif row['Generation'] == 'generation-iii':
        mainseries_ability_df.loc[index,'Generation'] = '3'
    elif row['Generation'] == 'generation-iv':
        mainseries_ability_df.loc[index,'Generation'] = '4'
    elif row['Generation'] == 'generation-v':
        mainseries_ability_df.loc[index,'Generation'] = '5'
    elif row['Generation'] == 'generation-vi':
        mainseries_ability_df.loc[index,'Generation'] = '6'
    elif row['Generation'] == 'generation-vii':
        mainseries_ability_df.loc[index,'Generation'] = '7'
    elif row['Generation'] == 'generation-viii':
        mainseries_ability_df.loc[index,'Generation'] = '8'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
mainseries_ability_df.head()
# Out:
#    ID          Name Generation  Is_Main_Series  \
# 0   1        Stench          3            True
# 1   2       Drizzle          3            True
# 2   3   Speed-boost          3            True
# 3   4  Battle-armor          3            True
# 4   5        Sturdy          3            True
#
#                                       Effect_changes  \
# 0  [{'effect_entries': [{'effect': 'Hat im Kampf ...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'effect_entries': [{'effect': 'Verhindert ke...
#
#                                       Effect_entries  \
# 0  This Pokémon's damaging moves have a 10% chanc...
# 1  The weather changes to rain when this Pokémon ...
# 2  This Pokémon's Speed rises one stage after eac...
# 3  Moves cannot score critical hits against this ...
# 4  When this Pokémon is at full HP, any hit that ...
#
#                                              Pokemon
# 0  [{'is_hidden': True, 'pokemon': {'name': 'gloo...
# 1  [{'is_hidden': True, 'pokemon': {'name': 'poli...
# 2  [{'is_hidden': False, 'pokemon': {'name': 'yan...
# 3  [{'is_hidden': True, 'pokemon': {'name': 'cubo...
# 4  [{'is_hidden': False, 'pokemon': {'name': 'geo...

# %%
mainseries_ability_df.tail()
# Out:
#       ID              Name Generation  Is_Main_Series Effect_changes  \
# 262  263       Dragons-maw          8            True             []
# 263  264    Chilling-neigh          8            True             []
# 264  265        Grim-neigh          8            True             []
# 265  266  As-one-glastrier          8            True             []
# 266  267  As-one-spectrier          8            True             []
#
#     Effect_entries                                            Pokemon
# 262            NaN  [{'is_hidden': False, 'pokemon': {'name': 'reg...
# 263            NaN  [{'is_hidden': False, 'pokemon': {'name': 'gla...
# 264            NaN  [{'is_hidden': False, 'pokemon': {'name': 'spe...
# 265            NaN  [{'is_hidden': False, 'pokemon': {'name': 'cal...
# 266            NaN  [{'is_hidden': False, 'pokemon': {'name': 'cal...

# %%
#Salvataggio sia in .csv che in .json
mainseries_ability_df.to_json("API_datasets\DATASET PER INTEGRAZIONE\Abilities.json.gz", orient='records', lines=True, compression='gzip')
mainseries_ability_df.to_csv("API_datasets\DATASET PER INTEGRAZIONE\Abilities.csv")

# %% [markdown]
# ### Natures

# %%
nature_df.Name = nature_df.Name.str.capitalize()
nature_df.tail()
# Out:
#     ID     Name                                     Decreased_stat  \
# 20  21    Brave  {'name': 'speed', 'url': 'https://pokeapi.co/a...
# 21  22  Relaxed  {'name': 'speed', 'url': 'https://pokeapi.co/a...
# 22  23    Quiet  {'name': 'speed', 'url': 'https://pokeapi.co/a...
# 23  24    Sassy  {'name': 'speed', 'url': 'https://pokeapi.co/a...
# 24  25  Serious                                               None
#
#                                        Increased_stat
# 20  {'name': 'attack', 'url': 'https://pokeapi.co/...
# 21  {'name': 'defense', 'url': 'https://pokeapi.co...
# 22  {'name': 'special-attack', 'url': 'https://pok...
# 23  {'name': 'special-defense', 'url': 'https://po...
# 24                                               None

# %%
for i in (nature_df['ID'].values):
    try:
        nature_df.loc[i-1, 'Decreased_stat'] = nature_df[nature_df['ID'] == i]['Decreased_stat'][i-1]['name']
        nature_df.loc[i-1, 'Increased_stat'] = nature_df[nature_df['ID'] == i]['Increased_stat'][i-1]['name']
    except TypeError:
        nature_df.loc[i-1, 'Decreased_stat'] = np.NaN
        nature_df.loc[i-1, 'Increased_stat'] = np.NaN

# %%
nature_df.Decreased_stat = nature_df.Decreased_stat.str.capitalize()
nature_df.Increased_stat = nature_df.Increased_stat.str.capitalize()
nature_df
# Out:
#     ID     Name   Decreased_stat   Increased_stat
# 0    1    Hardy              NaN              NaN
# 1    2     Bold           Attack          Defense
# 2    3   Modest           Attack   Special-attack
# 3    4     Calm           Attack  Special-defense
# 4    5    Timid           Attack            Speed
# 5    6   Lonely          Defense           Attack
# 6    7   Docile              NaN              NaN
# 7    8     Mild          Defense   Special-attack
# 8    9   Gentle          Defense  Special-defense
# 9   10    Hasty          Defense            Speed
# 10  11  Adamant   Special-attack           Attack
# 11  12   Impish   Special-attack          Defense
# 12  13  Bashful              NaN              NaN
# 13  14  Careful   Special-attack  Special-defense
# 14  15     Rash  Special-defense   Special-attack
# 15  16    Jolly   Special-attack            Speed
# 16  17  Naughty  Special-defense           Attack
# 17  18      Lax  Special-defense          Defense
# 18  19   Quirky              NaN              NaN
# 19  20    Naive  Special-defense            Speed
# 20  21    Brave            Speed           Attack
# 21  22  Relaxed            Speed          Defense
# 22  23    Quiet            Speed   Special-attack
# 23  24    Sassy            Speed  Special-defense
# 24  25  Serious              NaN              NaN

# %% [markdown]
# ### Stats

# %%
stat_df.Name = stat_df.Name.str.capitalize()
stat_df
# Out:
#    ID             Name                                    Affecting_moves  \
# 0   1               Hp                   {'decrease': [], 'increase': []}
# 1   2           Attack  {'decrease': [{'change': -1, 'move': {'name': ...
# 2   3          Defense  {'decrease': [{'change': -1, 'move': {'name': ...
# 3   4   Special-attack  {'decrease': [{'change': -1, 'move': {'name': ...
# 4   5  Special-defense  {'decrease': [{'change': -1, 'move': {'name': ...
# 5   6            Speed  {'decrease': [{'change': -1, 'move': {'name': ...
# 6   7         Accuracy  {'decrease': [{'change': -1, 'move': {'name': ...
# 7   8          Evasion  {'decrease': [{'change': -2, 'move': {'name': ...
#
#                                    Affecting_natures  \
# 0                   {'decrease': [], 'increase': []}
# 1  {'decrease': [{'name': 'bold', 'url': 'https:/...
# 2  {'decrease': [{'name': 'lonely', 'url': 'https...
# 3  {'decrease': [{'name': 'adamant', 'url': 'http...
# 4  {'decrease': [{'name': 'rash', 'url': 'https:/...
# 5  {'decrease': [{'name': 'brave', 'url': 'https:...
# 6                   {'decrease': [], 'increase': []}
# 7                   {'decrease': [], 'increase': []}
#
#                                    Move_damage_class
# 0                                               None
# 1  {'name': 'physical', 'url': 'https://pokeapi.c...
# 2  {'name': 'physical', 'url': 'https://pokeapi.c...
# 3  {'name': 'special', 'url': 'https://pokeapi.co...
# 4  {'name': 'special', 'url': 'https://pokeapi.co...
# 5                                               None
# 6                                               None
# 7                                               None

# %%
for i in (stat_df['ID'].values):
    try:
        stat_df.loc[i-1, 'Move_damage_class'] = stat_df[stat_df['ID'] == i]['Move_damage_class'][i-1]['name']
    except TypeError:
        stat_df.loc[i-1, 'Move_damage_class'] = np.NaN

# %%
stat_df.Move_damage_class = stat_df.Move_damage_class.str.capitalize()
stat_df
# Out:
#    ID             Name                                    Affecting_moves  \
# 0   1               Hp                   {'decrease': [], 'increase': []}
# 1   2           Attack  {'decrease': [{'change': -1, 'move': {'name': ...
# 2   3          Defense  {'decrease': [{'change': -1, 'move': {'name': ...
# 3   4   Special-attack  {'decrease': [{'change': -1, 'move': {'name': ...
# 4   5  Special-defense  {'decrease': [{'change': -1, 'move': {'name': ...
# 5   6            Speed  {'decrease': [{'change': -1, 'move': {'name': ...
# 6   7         Accuracy  {'decrease': [{'change': -1, 'move': {'name': ...
# 7   8          Evasion  {'decrease': [{'change': -2, 'move': {'name': ...
#
#                                    Affecting_natures Move_damage_class
# 0                   {'decrease': [], 'increase': []}               NaN
# 1  {'decrease': [{'name': 'bold', 'url': 'https:/...          Physical
# 2  {'decrease': [{'name': 'lonely', 'url': 'https...          Physical
# 3  {'decrease': [{'name': 'adamant', 'url': 'http...           Special
# 4  {'decrease': [{'name': 'rash', 'url': 'https:/...           Special
# 5  {'decrease': [{'name': 'brave', 'url': 'https:...               NaN
# 6                   {'decrease': [], 'increase': []}               NaN
# 7                   {'decrease': [], 'increase': []}               NaN

# %% [markdown]
# ### Types

# %%
type_df.Name = type_df.Name.str.capitalize()

#Resetto gli indici
for i in range(0, type_df.shape[0]):
    type_df.loc[i, 'ID'] = i+1
    
type_df.tail()
# Out:
#     ID                                         Game_index     Name  \
# 15  16  [{'game_index': 26, 'generation': {'name': 'ge...   Dragon
# 16  17  [{'game_index': 27, 'generation': {'name': 'ge...     Dark
# 17  18  [{'game_index': 17, 'generation': {'name': 'ge...    Fairy
# 18  19  [{'game_index': 19, 'generation': {'name': 'ge...  Unknown
# 19  20                                                 []   Shadow
#
#                                        Introducted_in  \
# 15  {'name': 'generation-i', 'url': 'https://pokea...
# 16  {'name': 'generation-ii', 'url': 'https://poke...
# 17  {'name': 'generation-vi', 'url': 'https://poke...
# 18  {'name': 'generation-ii', 'url': 'https://poke...
# 19  {'name': 'generation-iii', 'url': 'https://pok...
#
#                                      Damage_relations
# 15  {'double_damage_from': [{'name': 'ice', 'url':...
# 16  {'double_damage_from': [{'name': 'fighting', '...
# 17  {'double_damage_from': [{'name': 'poison', 'ur...
# 18  {'double_damage_from': [], 'double_damage_to':...
# 19  {'double_damage_from': [], 'double_damage_to':...

# %%
#Extract just the generation from 'Generation' lists 
for i in (type_df['ID'].values):
    type_df.loc[i-1, 'Introducted_in'] = type_df[type_df['ID'] == i]['Introducted_in'][i-1]['name']
    
type_df.tail()
# Out:
#     ID                                         Game_index     Name  \
# 15  16  [{'game_index': 26, 'generation': {'name': 'ge...   Dragon
# 16  17  [{'game_index': 27, 'generation': {'name': 'ge...     Dark
# 17  18  [{'game_index': 17, 'generation': {'name': 'ge...    Fairy
# 18  19  [{'game_index': 19, 'generation': {'name': 'ge...  Unknown
# 19  20                                                 []   Shadow
#
#     Introducted_in                                   Damage_relations
# 15    generation-i  {'double_damage_from': [{'name': 'ice', 'url':...
# 16   generation-ii  {'double_damage_from': [{'name': 'fighting', '...
# 17   generation-vi  {'double_damage_from': [{'name': 'poison', 'ur...
# 18   generation-ii  {'double_damage_from': [], 'double_damage_to':...
# 19  generation-iii  {'double_damage_from': [], 'double_damage_to':...

# %%
for index, row in type_df.iterrows():
    if row['Introducted_in'] == 'generation-i':
        type_df.loc[index,'Introducted_in'] = '1'
    elif row['Introducted_in'] == 'generation-ii':
        type_df.loc[index,'Introducted_in'] = '2'
    elif row['Introducted_in'] == 'generation-iii':
        type_df.loc[index,'Introducted_in'] = '3'
    elif row['Introducted_in'] == 'generation-iv':
        type_df.loc[index,'Introducted_in'] = '4'
    elif row['Introducted_in'] == 'generation-v':
        type_df.loc[index,'Introducted_in'] = '5'
    elif row['Introducted_in'] == 'generation-vi':
        type_df.loc[index,'Introducted_in'] = '6'
    elif row['Introducted_in'] == 'generation-vii':
        type_df.loc[index,'Introducted_in'] = '7'
    elif row['Introducted_in'] == 'generation-viii':
        type_df.loc[index,'Introducted_in'] = '8'

# %%
#Salvataggio sia in .csv che in .json
type_df.to_json("API_datasets\DATASET PER INTEGRAZIONE\Types.json.gz", orient='records', lines=True, compression='gzip')
type_df.to_csv("API_datasets\DATASET PER INTEGRAZIONE\Types.csv")
