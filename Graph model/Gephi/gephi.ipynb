# %%
import pandas as pd

# %%
pokemon_gephi = pok=pd.read_csv('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECT/DataManagement2022_Project/Dataset_import_Neo4j/df_pokemon_import.csv', sep=',')

# %%
pokemon_gephi['MonthlyUsageMarch2022']=pokemon_gephi['MonthlyUsageMarch2022'].replace('-', '',regex=True)
pokemon_gephi['UsagePercentMarch2022']=pokemon_gephi['UsagePercentMarch2022'].replace('-', '',regex=True)
pokemon_gephi['MonthlyRankMarch2022']=pokemon_gephi['MonthlyRankMarch2022'].replace('-', '',regex=True)
pokemon_gephi=pokemon_gephi.drop('Unnamed: 0',axis=1)
pokemon_gephi=pokemon_gephi.rename(columns={'Name':'Label'})
pokemon_gephi['id']=pokemon_gephi['Label']

# %%
display(pokemon_gephi)
pokemon_gephi.to_csv('pokemon_gephi.csv')
# Out:
#       NationalPokedexNumber                 Label    Species       Variant  \
# 0                         1             Bulbasaur  Bulbasaur           NaN
# 1                         2               Ivysaur    Ivysaur           NaN
# 2                         3              Venusaur   Venusaur           NaN
# 3                         3         Mega Venusaur   Venusaur          Mega
# 4                         3   Venusaur Gigantamax   Venusaur    Gigantamax
# ...                     ...                   ...        ...           ...
# 1093                    896             Glastrier  Glastrier           NaN
# 1094                    897             Spectrier  Spectrier           NaN
# 1095                    898               Calyrex    Calyrex           NaN
# 1096                    898  Calyrex Shadow Rider    Calyrex  Shadow Rider
# 1097                    898     Calyrex Ice Rider    Calyrex     Ice Rider
#
# ...

# %%
moves_gephi = pok=pd.read_csv('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECT/DataManagement2022_Project/Dataset_import_Neo4j/df_moves_import.csv', sep=',')
moves_gephi.head()
# Out:
#    Unnamed: 0        Name  IntroductedIn    Type  Power  Acc    PP  \
# 0           0      Absorb              1   Grass   20.0  100  25.0
# 1           1  Accelerock              7    Rock   40.0  100  20.0
# 2           2        Acid              1  Poison   40.0  100  30.0
# 3           3  Acid Armor              1  Poison    NaN  NaN  20.0
# 4           4  Acid Spray              5  Poison   40.0  100  20.0
#
#   DamageClass                                            Effect  \
# 0     Special  User recovers half the HP inflicted on opponent.
# 1    Physical                               User attacks first.
# 2     Special             May lower opponent's Special Defense.
# 3      Status                    Sharply raises user's Defense.
# 4     Special        Sharply lowers opponent's Special Defense.
#
#    ProbPercentage
# 0             NaN
# 1             NaN
# 2            10.0
# 3             NaN
# 4           100.0

# %%
moves_gephi=moves_gephi.drop('Unnamed: 0',axis=1)
moves_gephi=moves_gephi.rename(columns={'Name':'Label'})
moves_gephi['id']=moves_gephi['Label']

# %%
display(moves_gephi)
moves_gephi.to_csv('moves_gephi.csv', sep=';')
# Out:
#                 Label  IntroductedIn    Type  Power  Acc    PP DamageClass  \
# 0              Absorb              1   Grass   20.0  100  25.0     Special
# 1          Accelerock              7    Rock   40.0  100  20.0    Physical
# 2                Acid              1  Poison   40.0  100  30.0     Special
# 3          Acid Armor              1  Poison    NaN  NaN  20.0      Status
# 4          Acid Spray              5  Poison   40.0  100  20.0     Special
# ..                ...            ...     ...    ...  ...   ...         ...
# 816      G-Max Finale              8   Fairy    NaN    ∞   5.0         NaN
# 817  G-Max Steelsurge              8   Steel    NaN    ∞   5.0         NaN
# 818   G-Max Depletion              8  Dragon    NaN    ∞   5.0         NaN
# 819    G-Max One Blow              8    Dark    NaN    ∞   5.0         NaN
# 820  G-Max Rapid Flow              8   Water    NaN    ∞   5.0         NaN
#
# ...

# %%
types_gephi=pd.read_csv('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECT/DataManagement2022_Project/Dataset_import_Neo4j/df_types_import.csv', sep=',')
types_gephi.head()
# Out:
#    Unnamed: 0      Name  Generation
# 0           0    normal           1
# 1           1  fighting           1
# 2           2    flying           1
# 3           3    poison           1
# 4           4    ground           1

# %%
types_gephi=types_gephi.drop('Unnamed: 0',axis=1)
types_gephi=types_gephi.rename(columns={'Name':'Label'})
types_gephi['id']=types_gephi['Label']

# %%
display(types_gephi)
types_gephi.to_csv('types_gephi.csv', sep=';')
# Out:
#        Label  Generation        id
# 0     normal           1    normal
# 1   fighting           1  fighting
# 2     flying           1    flying
# 3     poison           1    poison
# 4     ground           1    ground
# 5       rock           1      rock
# 6        bug           1       bug
# 7      ghost           1     ghost
# 8      steel           2     steel
# 9       fire           1      fire
# 10     water           1     water
# 11     grass           1     grass
# 12  electric           1  electric
# 13   psychic           1   psychic
# 14       ice           1       ice
# 15    dragon           1    dragon
# 16      dark           2      dark
# 17     fairy           6     fairy
# 18   unknown           2   unknown
# 19    shadow           3    shadow

# %%
natures_gephi=pd.read_csv('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECT/DataManagement2022_Project/Dataset_import_Neo4j/df_natures_import.csv', sep=',')
natures_gephi.head()
# Out:
#    Unnamed: 0 NatureName Increases Decreases LikesBerrie DislikesBerrie
# 0           0    Adamant    Attack   Sp. Atk       Spicy            Dry
# 1           1    Bashful   Sp. Atk   Sp. Atk         Dry            Dry
# 2           2       Bold   Defense    Attack        Sour          Spicy
# 3           3      Brave    Attack     Speed       Spicy          Sweet
# 4           4       Calm   Sp. Def    Attack      Bitter          Spicy

# %%
natures_gephi=natures_gephi.drop('Unnamed: 0',axis=1)
natures_gephi=natures_gephi.rename(columns={'NatureName':'Label'})
natures_gephi['id']=natures_gephi['Label']

# %%
display(natures_gephi)
natures_gephi.to_csv('natures_gephi.csv', sep=';')
# Out:
#       Label Increases Decreases LikesBerrie DislikesBerrie       id
# 0   Adamant    Attack   Sp. Atk       Spicy            Dry  Adamant
# 1   Bashful   Sp. Atk   Sp. Atk         Dry            Dry  Bashful
# 2      Bold   Defense    Attack        Sour          Spicy     Bold
# 3     Brave    Attack     Speed       Spicy          Sweet    Brave
# 4      Calm   Sp. Def    Attack      Bitter          Spicy     Calm
# 5   Careful   Sp. Def   Sp. Atk      Bitter            Dry  Careful
# 6    Docile   Defense   Defense        Sour           Sour   Docile
# 7    Gentle   Sp. Def   Defense      Bitter           Sour   Gentle
# 8     Hardy    Attack    Attack       Spicy          Spicy    Hardy
# 9     Hasty     Speed   Defense       Sweet           Sour    Hasty
# 10   Impish   Defense   Sp. Atk        Sour            Dry   Impish
# 11    Jolly     Speed   Sp. Atk       Sweet            Dry    Jolly
# 12      Lax   Defense   Sp. Def        Sour         Bitter      Lax
# ...

# %%
items_gephi=pd.read_csv('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECT/DataManagement2022_Project/Dataset_import_Neo4j/df_items_import.csv', sep=',')
items_gephi.head()
# Out:
#    Unnamed: 0             Name  \
# 0           0  Ability Capsule
# 1           1    Ability Patch
# 2           2     Ability Urge
# 3           3        Abomasite
# 4           4         Absolite
#
#                                    AlternativeEffect  \
# 0  Switches a Pokémon between its two possible (n...
# 1                                                NaN
# 2   Forcibly activates a friendly Pokémon's ability.
# 3  Held: Allows Abomasnow to Mega Evolve into Meg...
# 4  Held: Allows Absol to Mega Evolve into Mega Ab...
#
#                                               Effect UsageAttributes  \
# 0  A capsule that allows a Pokémon with two Abili...             NaN
# 1  Changes a Pokémon's ability to its Hidden Abil...             NaN
# 2  When used, it activates the Ability of an ally...             NaN
# 3    Enables Abomasnow to Mega Evolve during battle.             NaN
# 4        Enables Absol to Mega Evolve during battle.             NaN
#
# ...

# %%
items_gephi=items_gephi.drop('Unnamed: 0',axis=1)
items_gephi=items_gephi.rename(columns={'Name':'Label'})
items_gephi['id']=items_gephi['Label']

# %%
display(items_gephi)
items_gephi.to_csv('items_gephi.csv', sep=';')
# Out:
#                Label                                  AlternativeEffect  \
# 0    Ability Capsule  Switches a Pokémon between its two possible (n...
# 1      Ability Patch                                                NaN
# 2       Ability Urge   Forcibly activates a friendly Pokémon's ability.
# 3          Abomasite  Held: Allows Abomasnow to Mega Evolve into Meg...
# 4           Absolite  Held: Allows Absol to Mega Evolve into Mega Ab...
# ..               ...                                                ...
# 835     Yellow Scarf  Raises the holder's Toughness while in a contest.
# 836     Yellow Shard       No effect. Can be traded for items or moves.
# 837        Zap Plate  Held: Electric-Type moves from holder do 20% m...
# 838             Zinc              Raises Special Defense and happiness.
# 839        Zoom Lens  Held: Provides a 1/5 (20%) boost in accuracy i...
#
#                                                 Effect  \
# ...

# %%
abilities_gephi=pd.read_csv('C:/Users/marco/OneDrive/UNIMIB_DataScience/99-PROJECT/DataManagement2022_Project/Dataset_import_Neo4j/df_abilities_import.csv', sep=',')
abilities_gephi.head()
# Out:
#    Unnamed: 0          Name  Generation  \
# 0           0  Adaptability           4
# 1           1      Aerilate           6
# 2           2     Aftermath           4
# 3           3      Air Lock           3
# 4           4      Analytic           5
#
#                                        Description
# 0                Powers up moves of the same type.
# 1  Turns Normal-type moves into Flying-type moves.
# 2  Damages the attacker landing the finishing hit.
# 3               Eliminates the effects of weather.
# 4   Boosts move power when the Pokémon moves last.

# %%
abilities_gephi=abilities_gephi.drop('Unnamed: 0',axis=1)
abilities_gephi=abilities_gephi.rename(columns={'Name':'Label'})
abilities_gephi['id']=abilities_gephi['Label']

# %%
display(abilities_gephi)
abilities_gephi.to_csv('abilities_gephi.csv', sep=';')
# Out:
#             Label  Generation  \
# 0    Adaptability           4
# 1        Aerilate           6
# 2       Aftermath           4
# 3        Air Lock           3
# 4        Analytic           5
# ..            ...         ...
# 262   White Smoke           3
# 263      Wimp Out           7
# 264  Wonder Guard           3
# 265   Wonder Skin           5
# 266      Zen Mode           5
#
#                                           Description            id
# 0                   Powers up moves of the same type.  Adaptability
# 1     Turns Normal-type moves into Flying-type moves.      Aerilate
# 2     Damages the attacker landing the finishing hit.     Aftermath
# 3                  Eliminates the effects of weather.      Air Lock
# 4      Boosts move power when the Pokémon moves last.      Analytic
# ..                                                ...           ...
# 262   Prevents other Pokémon from lowering its stats.   White Smoke
# ...
